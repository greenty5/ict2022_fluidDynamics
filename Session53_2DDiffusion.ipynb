# %% [markdown]
# <a href="https://colab.research.google.com/github/greenty5/ict2022_fluidDynamics/blob/main/Session53_2DDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fluid Dynamics with Python (ICT Summer School 2022)
# =====
# ***

# %% [markdown]
# You see where this is going ... we'll do 2D diffusion now and next we will combine steps 6 and 7 to solve Burgers' equation. So make sure your previous steps work well before continuing.

# %% [markdown]
# 2D Diffusion
# ----
# ***

# %% [markdown]
# And here is the 2D-diffusion equation:
#
# $$\frac{\partial u}{\partial t} = \nu \frac{\partial ^2 u}{\partial x^2} + \nu \frac{\partial ^2 u}{\partial y^2}$$
#
# You will recall that we came up with a method for discretizing second order derivatives in the previous sessions, when investigating 1-D diffusion.  We are going to use the same scheme here, with our forward difference in time and two second-order derivatives.

# %% [markdown]
# <font color='orange'>
# $$\cdots + \nu \frac{u_{i,j+1}^n-2 u_{i,j}^n + u_{i,j-1}^n}{\Delta y^2}$$
# </font>
#
# Once again, we reorganize the discretized equation and solve for $u_{i,j}^{n+1}$

# %% [markdown]
# <font color='orange'>
# $$
# u_{i,j}^{n+1} = \cdots
# $$
# </font>

# %%
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D ##library for 3d projection plots
# %matplotlib inline

# %%
###variable declarations
nx = 31
ny = 31
nt = 17
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

# write your own code here




# create u and un vectors




###Assign initial conditions
# set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, u, rstride=1, cstride=1, cmap=cm.viridis,
        linewidth=0, antialiased=False)

ax.set_xlim(0, 2)
ax.set_ylim(0, 2)
ax.set_zlim(1, 2.5)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$');

# %%
###Run through nt timesteps
def diffuse(nt):
    # write you own code and try drawing 3D graphs mentiond below;



    
    fig = plt.figure(figsize=(8, 6), dpi=100)
    ax = fig.gca(projection='3d')
    surf = ax.plot_surface(X, Y, u[:], rstride=1, cstride=1, cmap=cm.viridis,
        linewidth=0, antialiased=True)
    ax.set_zlim(1, 2.5)
    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$');

# %%
diffuse(10)

# %%
diffuse(14)

# %%
diffuse(50)
