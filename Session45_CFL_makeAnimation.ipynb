# %% [markdown]
# <a href="https://colab.research.google.com/github/greenty5/ict2022_fluidDynamics/blob/main/Session45_CFL_makeAnimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fluid Dynamics with Python (ICT Summer School 2022)
# Section 3.3 Animation + Calculation Results
# =====
# ***

# %% [markdown]
# Last session, we learned how discretization parameters affected our solution drastically.
# In this session, we will learn the influence of discretization parameters by making wave traveling animation.

# %% [markdown]
# Animation + Calculation results
# ---
# ***

# %% [markdown]
# $$\frac{\partial u}{\partial t} = c \frac{\partial u}{\partial x}$$
#
# This 1-D advection equation shows __spatial__ and __time__ changes of wave. Last session we only confirmed wave traveling and wave form at arbitaral time. Let us make some animations showing wave traveling characteristics and confirm how discretization parameters affects on our solution.

# %% [markdown]
# First of all, we have to import some libraries such as __numpy__, __matplotlib.pyplot__. In addition we have to import `matplotlib.animation`, `matplotlib.rc` and `IPython.display.HTML` libraries to make animation.

# %%
import numpy as np                 #numpy is a library for array operations
from matplotlib import pyplot as plt    #matplotlib is 2D plotting library
from matplotlib import animation, rc
from IPython.display import HTML

# %%
nx = 40 # number of grid nodes

dx = 2 / (nx - 1)
nt = 20    #nt is the number of timesteps we want to calculate
dt = .025  #dt is the amount of time each timestep covers (delta t)
c = 1








anim = animation.ArtistAnimation(fig, ims, interval=200)

rc('animation', html='jshtml')
plt.close()
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ***

# %% [markdown]
# Please note that making animation needs a little bit heavy calculaiton to Google colaboratory. In this course, we will use the animation only in 1-D calculation.

# %% [markdown]
# Good job everyone 😃
